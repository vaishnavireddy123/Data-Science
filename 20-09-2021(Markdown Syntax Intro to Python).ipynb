# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading6

# %% [markdown]
# **Bold**
# *Italic*
# ***Bold and italic***

# %% [markdown]
# ### Ordered list
# **Data Science**
# 1.Numpy
# 2.Pandas
# 3.Visualization
#    A.Matplotlib
#    B.Seaborn

# %% [markdown]
# #### Unordered list
# - CSE
# - ECE
#      .Mech

# %% [markdown]
# #### To insert a link
#
# [APSSDC](apssdc.in)

# %% [markdown]
# #### To insert an image
# ![Image](![Screenshot%20%2831%29.png](attachment:Screenshot%20%2831%29.png))

# %% [markdown]
# ![Screenshot%20%2831%29.png](attachment:Screenshot%20%2831%29.png)
